# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams

# %matplotlib inline

# %% [markdown]
# ### Задание 1

# %%
x = np.array([1, 2, 3, 4, 5, 6, 7])
y = np.array([3.5, 3.8, 4.2, 4.5, 5, 5.5, 7.])

# %%
plt.plot(x, y, marker = 'o')
plt.show()

# %%
df = pd.DataFrame([x, y])
df.index = ['x', 'y']
df = df.transpose()
df
# Out:
#      x    y
# 0  1.0  3.5
# 1  2.0  3.8
# 2  3.0  4.2
# 3  4.0  4.5
# 4  5.0  5.0
# 5  6.0  5.5
# 6  7.0  7.0

# %%
ax1 = df.plot.scatter(x='x',y='y',c='DarkBlue')

# %%
# просто для ознакомления
ax1 = df.plot.scatter(x='x',y='y', c='x', colormap='viridis')

# %% [markdown]
# ### Задание 2

# %%
t = np.linspace(0, 10, num = 51, endpoint = True)

# %%
f = np.cos(t)

# %%
plt.axis([0.5, 9.5, -2.5, 2.5])
plt.plot(t, f, color = 'green')
plt.title('График f(t)')
plt.xlabel('Значения t')
plt.ylabel('Значения f')
plt.show()

# %% [markdown]
# ### Задание 3

# %%
x = np.linspace(0, 10, num = 51, endpoint = True)

# %%
x
# Out:
# array([ 0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2,  1.4,  1.6,  1.8,  2. ,
#         2.2,  2.4,  2.6,  2.8,  3. ,  3.2,  3.4,  3.6,  3.8,  4. ,  4.2,
#         4.4,  4.6,  4.8,  5. ,  5.2,  5.4,  5.6,  5.8,  6. ,  6.2,  6.4,
#         6.6,  6.8,  7. ,  7.2,  7.4,  7.6,  7.8,  8. ,  8.2,  8.4,  8.6,
#         8.8,  9. ,  9.2,  9.4,  9.6,  9.8, 10. ])

# %%
y1 = x**2
y2 = 2 * x + 0.5
y3 = -3 * x - 1.5
y4 = np.sin(x)

# %%
plt.subplots?

# %%
x0 = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

# %%
fig, ax = plt.subplots(2, 2)
ax[0, 0].plot(x, y1)
ax[0, 1].plot(x, y2)
ax[1, 0].plot(x, y3)
ax[1, 1].plot(x, y4)
ax[0, 0].set_title('График y1')
ax[0, 1].set_title('График y2')
ax[1, 0].set_title('График y3')
ax[1, 1].set_title('График y4')
ax[0, 0].set_xlim([-5, 5])
fig.set_size_inches(8, 6)
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.3)

# %%
plt.value_counts?
# Out:
# Object `plt.value_counts` not found.

# %% [markdown]
# ### Задание 4

# %%
plt.style.use('fivethirtyeight')

# %%
creditcard = pd.read_csv('creditcard.csv')

# %%
creditcard[:5]
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
class_count = creditcard['Class'].value_counts()

# %%
class_count.shape
# Out:
# (2,)

# %%
class_count.plot(kind='hist', logx=True)

# %%
creditcard.query("Class == 1")['V1'].plot(kind='hist')

# %%
creditcard.query("Class == 0")['V1'].plot(kind='hist')

# %%
# выборка другим способом, не query
creditcard.loc[creditcard['Class'] == 0, 'V1']
# Out:
# 0         -1.359807
# 1          1.191857
# 2         -1.358354
# 3         -0.966272
# 4         -1.158233
# 5         -0.425966
# 6          1.229658
# 7         -0.644269
# 8         -0.894286
# 9         -0.338262
# 10         1.449044
# 11         0.384978
# 12         1.249999
# 13         1.069374
# 14        -2.791855
# 15        -0.752417
# 16         1.103215
# 17        -0.436905
# 18        -5.401258
# 19         1.492936
# 20         0.694885
# 21         0.962496
# 22         1.166616
# 23         0.247491
# 24        -1.946525
# 25        -2.074295
# 26         1.173285
# 27         1.322707
# 28        -0.414289
# 29         1.059387
#             ...
# 284777     2.079137
# 284778    -0.764523
# 284779     1.975178
# 284780    -1.727503
# 284781    -1.139015
# 284782    -0.268061
# 284783    -1.796092
# 284784    -0.669662
# 284785     0.032887
# 284786    -2.076175
# 284787    -1.029719
# 284788     2.007418
# 284789    -0.446951
# 284790    -0.515513
# ...

# %%
hist0 = creditcard.loc[creditcard['Class'] == 0, 'V1']
hist1 = creditcard.loc[creditcard['Class'] == 1, 'V1']
fig, ax = plt.subplots()
ax = fig.add_subplot(111)
_ = ax.hist(hist0.values, color='grey', alpha=.5, bins = 20, density = 10, log = True, label = 'Class 0')
_ = ax.hist(hist1.values, color='red', alpha=.5, bins = 20, density = 20, log = True, label = 'Class 1')
ax.legend(loc='upper left')
